# %%
# Import the Pandas library for data manipulation
import pandas as pd

# %%
# Load the dataset from a CSV file
df = pd.read_csv("movie.csv")

# %%
# Display the first few rows of the dataset to get an overview
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 4911  ...                  6.0  English   Canada             NaN          NaN
# 4912  ...                359.0  English      USA           TV-14          NaN
# 4913  ...                  3.0  English      USA             NaN       1400.0
# 4914  ...                  9.0  English      USA           PG-13          NaN
# 4915  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
# 4913      2013.0                    0.0        6.3           NaN
# 4914      2012.0                  719.0        6.3          2.35
# 4915      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 4911                   84
# 4912                32000
# 4913                   16
# 4914                  660
# 4915                  456
#
# [4916 rows x 28 columns]

# %%
# Get the number of rows and columns in the DataFrame
nrows, ncols = df.shape
print(f"Number of rows: {nrows} \nNumber of columns: {ncols}")
# Out:
# Number of rows: 4916
# Number of columns: 28

# %%
# Display the data types of each column
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
# Count the occurrences of each data type in the DataFrame
df.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# Name: count, dtype: int64

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
# Step 1: Handle Missing Values
# Fill numerical columns with the median value and categorical columns with the mode
for column in df.columns:
    if df[column].dtype == 'float64' or df[column].dtype == 'int64': # Check for numerical columns
        df[column].fillna(df[column].median(), inplace=True) # Fill missing values with median
    else:
        df[column].fillna(df[column].mode()[0], inplace=True) # Fill missing values with mode

# %%
# Verify that there are no more missing values
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
# Step 2: Filter Data
# Filtering the dataset to only include movies with an IMDb score greater than 7.0
filtered_df = df[df['imdb_score'] > 7.0]

# %%
# Convert all column names to uppercase for consistency
filtered_df.rename(columns= lambda label: label.upper(), inplace=True)
# Out:
# C:\Users\Habibullah\AppData\Local\Temp\ipykernel_9824\1783481461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.rename(columns= lambda label: label.upper(), inplace=True)

# %%
# Select the "MOVIE_TITLE" column to view movie titles
filtered_df["MOVIE_TITLE"]
# Out:
# 0                                           Avatar
# 1         Pirates of the Caribbean: At World's End
# 3                            The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens
# 7                                          Tangled
#                            ...
# 4900                                    The Circle
# 4902                                      The Cure
# 4909                               The Mongol King
# 4911                       Signed Sealed Delivered
# 4912                                 The Following
# Name: MOVIE_TITLE, Length: 1546, dtype: object

# %%
# Set "MOVIE_TITLE" as the index of the DataFrame
filtered_df.set_index('MOVIE_TITLE',inplace=True)

# %%
# Display the DataFrame with "MOVIE_TITLE" as the index
filtered_df
# Out:
#                                             COLOR      DIRECTOR_NAME  \
# MOVIE_TITLE
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens  Color        Doug Walker
# Tangled                                     Color       Nathan Greno
# ...                                           ...                ...
# The Circle                                  Color       Jafar Panahi
# The Cure                                    Color   Kiyoshi Kurosawa
# The Mongol King                             Color    Anthony Vallone
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color   Steven Spielberg
#
#                                             NUM_CRITIC_FOR_REVIEWS  DURATION  \
# MOVIE_TITLE
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                   108.0     103.0
# Tangled                                                      324.0     100.0
# ...                                                            ...       ...
# The Circle                                                    64.0      90.0
# The Cure                                                      78.0     111.0
# The Mongol King                                              108.0      84.0
# Signed Sealed Delivered                                        1.0      87.0
# The Following                                                 43.0      43.0
#
#                                             DIRECTOR_FACEBOOK_LIKES  \
# MOVIE_TITLE
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
# Tangled                                                        15.0
# ...                                                             ...
# The Circle                                                    397.0
# The Cure                                                       62.0
# The Mongol King                                                 2.0
# Signed Sealed Delivered                                         2.0
# The Following                                                  48.0
#
#                                             ACTOR_3_FACEBOOK_LIKES  \
# MOVIE_TITLE
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                   366.0
# Tangled                                                      284.0
# ...                                                            ...
# The Circle                                                     0.0
# The Cure                                                       6.0
# The Mongol King                                                2.0
# Signed Sealed Delivered                                      318.0
# The Following                                                319.0
#
#                                                  ACTOR_2_NAME  \
# MOVIE_TITLE
# Avatar                                       Joel David Moore
# Pirates of the Caribbean: At World's End        Orlando Bloom
# The Dark Knight Rises                          Christian Bale
# Star Wars: Episode VII - The Force Awakens         Rob Walker
# Tangled                                          Donna Murphy
# ...                                                       ...
# The Circle                                  Nargess Mamizadeh
# The Cure                                        Anna Nakagawa
# The Mongol King                                John Considine
# Signed Sealed Delivered                         Daphne Zuniga
# The Following                                   Valorie Curry
#
#                                             ACTOR_1_FACEBOOK_LIKES  \
# MOVIE_TITLE
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# Tangled                                                      799.0
# ...                                                            ...
# The Circle                                                     5.0
# The Cure                                                      89.0
# The Mongol King                                               45.0
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
#
#                                                   GROSS  \
# MOVIE_TITLE
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens   25043962.0
# Tangled                                     200807262.0
# ...                                                 ...
# The Circle                                     673780.0
# The Cure                                        94596.0
# The Mongol King                              25043962.0
# Signed Sealed Delivered                      25043962.0
# The Following                                25043962.0
#
#                                                                                        GENRES  \
# MOVIE_TITLE
# Avatar                                                        Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                             Action|Adventure|Fantasy
# The Dark Knight Rises                                                         Action|Thriller
# Star Wars: Episode VII - The Force Awakens                                        Documentary
# Tangled                                     Adventure|Animation|Comedy|Family|Fantasy|Musi...
# ...                                                                                       ...
# The Circle                                                                              Drama
# The Cure                                                        Crime|Horror|Mystery|Thriller
# The Mongol King                                                                   Crime|Drama
# Signed Sealed Delivered                                                          Comedy|Drama
# The Following                                                    Crime|Drama|Mystery|Thriller
#
#                                             ... NUM_USER_FOR_REVIEWS  \
# MOVIE_TITLE                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                153.0
# Tangled                                     ...                387.0
# ...                                         ...                  ...
# The Circle                                  ...                 26.0
# The Cure                                    ...                 50.0
# The Mongol King                             ...                  1.0
# Signed Sealed Delivered                     ...                  6.0
# The Following                               ...                359.0
#
#                                             LANGUAGE  COUNTRY CONTENT_RATING  \
# MOVIE_TITLE
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens   English      USA              R
# Tangled                                      English      USA             PG
# ...                                              ...      ...            ...
# The Circle                                   Persian     Iran      Not Rated
# The Cure                                    Japanese    Japan              R
# The Mongol King                              English      USA          PG-13
# Signed Sealed Delivered                      English   Canada              R
# The Following                                English      USA          TV-14
#
#                                                  BUDGET TITLE_YEAR  \
# MOVIE_TITLE
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens   19850000.0     2005.0
# Tangled                                     260000000.0     2010.0
# ...                                                 ...        ...
# The Circle                                      10000.0     2000.0
# The Cure                                      1000000.0     1997.0
# The Mongol King                                  3250.0     2005.0
# Signed Sealed Delivered                      19850000.0     2013.0
# The Following                                19850000.0     2005.0
#
#                                            ACTOR_2_FACEBOOK_LIKES  IMDB_SCORE  \
# MOVIE_TITLE
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
# Tangled                                                     553.0         7.8
# ...                                                           ...         ...
# The Circle                                                    0.0         7.5
# The Cure                                                     13.0         7.4
# The Mongol King                                              44.0         7.8
# Signed Sealed Delivered                                     470.0         7.7
# The Following                                               593.0         7.5
#
#                                            ASPECT_RATIO MOVIE_FACEBOOK_LIKES
# MOVIE_TITLE
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens         2.35                    0
# Tangled                                            1.85                29000
# ...                                                 ...                  ...
# The Circle                                         1.85                  697
# The Cure                                           1.85                  817
# The Mongol King                                    2.35                    4
# Signed Sealed Delivered                            2.35                   84
# The Following                                     16.00                32000
#
# [1546 rows x 27 columns]

# %%
# Access data for the movie titled "Avatar"
filtered_df.loc["Avatar"]
# Out:
# COLOR                                                                    Color
# DIRECTOR_NAME                                                    James Cameron
# NUM_CRITIC_FOR_REVIEWS                                                   723.0
# DURATION                                                                 178.0
# DIRECTOR_FACEBOOK_LIKES                                                    0.0
# ACTOR_3_FACEBOOK_LIKES                                                   855.0
# ACTOR_2_NAME                                                  Joel David Moore
# ACTOR_1_FACEBOOK_LIKES                                                  1000.0
# GROSS                                                              760505847.0
# GENRES                                         Action|Adventure|Fantasy|Sci-Fi
# ACTOR_1_NAME                                                       CCH Pounder
# NUM_VOTED_USERS                                                         886204
# CAST_TOTAL_FACEBOOK_LIKES                                                 4834
# ACTOR_3_NAME                                                         Wes Studi
# FACENUMBER_IN_POSTER                                                       0.0
# PLOT_KEYWORDS                           avatar|future|marine|native|paraplegic
# MOVIE_IMDB_LINK              http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# NUM_USER_FOR_REVIEWS                                                    3054.0
# LANGUAGE                                                               English
# COUNTRY                                                                    USA
# CONTENT_RATING                                                           PG-13
# BUDGET                                                             237000000.0
# TITLE_YEAR                                                              2009.0
# ACTOR_2_FACEBOOK_LIKES                                                   936.0
# IMDB_SCORE                                                                 7.9
# ASPECT_RATIO                                                              1.78
# MOVIE_FACEBOOK_LIKES                                                     33000
# Name: Avatar, dtype: object

# %%
# Display the index of the DataFrame, which should now be "MOVIE_TITLE"
filtered_df.index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End',
#        'The Dark Knight Rises', 'Star Wars: Episode VII - The Force Awakens',
#        'Tangled', 'Avengers: Age of Ultron',
#        'Harry Potter and the Half-Blood Prince',
#        'Pirates of the Caribbean: Dead Man's Chest', 'Man of Steel',
#        'The Avengers',
#        ...
#        'The Last Waltz', 'Clerks', 'In the Company of Men', 'Slacker',
#        'Stories of Our Lives', 'The Circle', 'The Cure', 'The Mongol King',
#        'Signed Sealed Delivered', 'The Following'],
#       dtype='object', name='MOVIE_TITLE', length=1546)

# %%
# Display the column names of the DataFrame
filtered_df.columns
# Out:
# Index(['COLOR', 'DIRECTOR_NAME', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES', 'ACTOR_2_NAME',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'GENRES', 'ACTOR_1_NAME',
#        'NUM_VOTED_USERS', 'CAST_TOTAL_FACEBOOK_LIKES', 'ACTOR_3_NAME',
#        'FACENUMBER_IN_POSTER', 'PLOT_KEYWORDS', 'MOVIE_IMDB_LINK',
#        'NUM_USER_FOR_REVIEWS', 'LANGUAGE', 'COUNTRY', 'CONTENT_RATING',
#        'BUDGET', 'TITLE_YEAR', 'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE',
#        'ASPECT_RATIO', 'MOVIE_FACEBOOK_LIKES'],
#       dtype='object')

# %%
# Rename the "MOVIE_IMDB_LINK" column to "IMDB_LINK" for simplicity
filtered_df.rename(columns={"MOVIE_IMDB_LINK" : "IMDB_LINK"})
# Out:
#                                             COLOR      DIRECTOR_NAME  \
# MOVIE_TITLE
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens  Color        Doug Walker
# Tangled                                     Color       Nathan Greno
# ...                                           ...                ...
# The Circle                                  Color       Jafar Panahi
# The Cure                                    Color   Kiyoshi Kurosawa
# The Mongol King                             Color    Anthony Vallone
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color   Steven Spielberg
#
#                                             NUM_CRITIC_FOR_REVIEWS  DURATION  \
# MOVIE_TITLE
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                   108.0     103.0
# Tangled                                                      324.0     100.0
# ...                                                            ...       ...
# The Circle                                                    64.0      90.0
# The Cure                                                      78.0     111.0
# The Mongol King                                              108.0      84.0
# Signed Sealed Delivered                                        1.0      87.0
# The Following                                                 43.0      43.0
#
#                                             DIRECTOR_FACEBOOK_LIKES  \
# MOVIE_TITLE
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
# Tangled                                                        15.0
# ...                                                             ...
# The Circle                                                    397.0
# The Cure                                                       62.0
# The Mongol King                                                 2.0
# Signed Sealed Delivered                                         2.0
# The Following                                                  48.0
#
#                                             ACTOR_3_FACEBOOK_LIKES  \
# MOVIE_TITLE
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                   366.0
# Tangled                                                      284.0
# ...                                                            ...
# The Circle                                                     0.0
# The Cure                                                       6.0
# The Mongol King                                                2.0
# Signed Sealed Delivered                                      318.0
# The Following                                                319.0
#
#                                                  ACTOR_2_NAME  \
# MOVIE_TITLE
# Avatar                                       Joel David Moore
# Pirates of the Caribbean: At World's End        Orlando Bloom
# The Dark Knight Rises                          Christian Bale
# Star Wars: Episode VII - The Force Awakens         Rob Walker
# Tangled                                          Donna Murphy
# ...                                                       ...
# The Circle                                  Nargess Mamizadeh
# The Cure                                        Anna Nakagawa
# The Mongol King                                John Considine
# Signed Sealed Delivered                         Daphne Zuniga
# The Following                                   Valorie Curry
#
#                                             ACTOR_1_FACEBOOK_LIKES  \
# MOVIE_TITLE
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# Tangled                                                      799.0
# ...                                                            ...
# The Circle                                                     5.0
# The Cure                                                      89.0
# The Mongol King                                               45.0
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
#
#                                                   GROSS  \
# MOVIE_TITLE
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens   25043962.0
# Tangled                                     200807262.0
# ...                                                 ...
# The Circle                                     673780.0
# The Cure                                        94596.0
# The Mongol King                              25043962.0
# Signed Sealed Delivered                      25043962.0
# The Following                                25043962.0
#
#                                                                                        GENRES  \
# MOVIE_TITLE
# Avatar                                                        Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                             Action|Adventure|Fantasy
# The Dark Knight Rises                                                         Action|Thriller
# Star Wars: Episode VII - The Force Awakens                                        Documentary
# Tangled                                     Adventure|Animation|Comedy|Family|Fantasy|Musi...
# ...                                                                                       ...
# The Circle                                                                              Drama
# The Cure                                                        Crime|Horror|Mystery|Thriller
# The Mongol King                                                                   Crime|Drama
# Signed Sealed Delivered                                                          Comedy|Drama
# The Following                                                    Crime|Drama|Mystery|Thriller
#
#                                             ... NUM_USER_FOR_REVIEWS  \
# MOVIE_TITLE                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                153.0
# Tangled                                     ...                387.0
# ...                                         ...                  ...
# The Circle                                  ...                 26.0
# The Cure                                    ...                 50.0
# The Mongol King                             ...                  1.0
# Signed Sealed Delivered                     ...                  6.0
# The Following                               ...                359.0
#
#                                             LANGUAGE  COUNTRY CONTENT_RATING  \
# MOVIE_TITLE
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens   English      USA              R
# Tangled                                      English      USA             PG
# ...                                              ...      ...            ...
# The Circle                                   Persian     Iran      Not Rated
# The Cure                                    Japanese    Japan              R
# The Mongol King                              English      USA          PG-13
# Signed Sealed Delivered                      English   Canada              R
# The Following                                English      USA          TV-14
#
#                                                  BUDGET TITLE_YEAR  \
# MOVIE_TITLE
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens   19850000.0     2005.0
# Tangled                                     260000000.0     2010.0
# ...                                                 ...        ...
# The Circle                                      10000.0     2000.0
# The Cure                                      1000000.0     1997.0
# The Mongol King                                  3250.0     2005.0
# Signed Sealed Delivered                      19850000.0     2013.0
# The Following                                19850000.0     2005.0
#
#                                            ACTOR_2_FACEBOOK_LIKES  IMDB_SCORE  \
# MOVIE_TITLE
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
# Tangled                                                     553.0         7.8
# ...                                                           ...         ...
# The Circle                                                    0.0         7.5
# The Cure                                                     13.0         7.4
# The Mongol King                                              44.0         7.8
# Signed Sealed Delivered                                     470.0         7.7
# The Following                                               593.0         7.5
#
#                                            ASPECT_RATIO MOVIE_FACEBOOK_LIKES
# MOVIE_TITLE
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens         2.35                    0
# Tangled                                            1.85                29000
# ...                                                 ...                  ...
# The Circle                                         1.85                  697
# The Cure                                           1.85                  817
# The Mongol King                                    2.35                    4
# Signed Sealed Delivered                            2.35                   84
# The Following                                     16.00                32000
#
# [1546 rows x 27 columns]

# %%
# Display the column names again to verify renaming
filtered_df.columns
# Out:
# Index(['COLOR', 'DIRECTOR_NAME', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES', 'ACTOR_2_NAME',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'GENRES', 'ACTOR_1_NAME',
#        'NUM_VOTED_USERS', 'CAST_TOTAL_FACEBOOK_LIKES', 'ACTOR_3_NAME',
#        'FACENUMBER_IN_POSTER', 'PLOT_KEYWORDS', 'MOVIE_IMDB_LINK',
#        'NUM_USER_FOR_REVIEWS', 'LANGUAGE', 'COUNTRY', 'CONTENT_RATING',
#        'BUDGET', 'TITLE_YEAR', 'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE',
#        'ASPECT_RATIO', 'MOVIE_FACEBOOK_LIKES'],
#       dtype='object')

# %%
# Remove "_FACEBOOK" suffix from any column names that have it
filtered_df.rename(columns=lambda label:label.replace("_FACEBOOK", ""))
# Out:
#                                             COLOR      DIRECTOR_NAME  \
# MOVIE_TITLE
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens  Color        Doug Walker
# Tangled                                     Color       Nathan Greno
# ...                                           ...                ...
# The Circle                                  Color       Jafar Panahi
# The Cure                                    Color   Kiyoshi Kurosawa
# The Mongol King                             Color    Anthony Vallone
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color   Steven Spielberg
#
#                                             NUM_CRITIC_FOR_REVIEWS  DURATION  \
# MOVIE_TITLE
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                   108.0     103.0
# Tangled                                                      324.0     100.0
# ...                                                            ...       ...
# The Circle                                                    64.0      90.0
# The Cure                                                      78.0     111.0
# The Mongol King                                              108.0      84.0
# Signed Sealed Delivered                                        1.0      87.0
# The Following                                                 43.0      43.0
#
#                                             DIRECTOR_LIKES  ACTOR_3_LIKES  \
# MOVIE_TITLE
# Avatar                                                 0.0          855.0
# Pirates of the Caribbean: At World's End             563.0         1000.0
# The Dark Knight Rises                              22000.0        23000.0
# Star Wars: Episode VII - The Force Awakens           131.0          366.0
# Tangled                                               15.0          284.0
# ...                                                    ...            ...
# The Circle                                           397.0            0.0
# The Cure                                              62.0            6.0
# The Mongol King                                        2.0            2.0
# Signed Sealed Delivered                                2.0          318.0
# The Following                                         48.0          319.0
#
#                                                  ACTOR_2_NAME  ACTOR_1_LIKES  \
# MOVIE_TITLE
# Avatar                                       Joel David Moore         1000.0
# Pirates of the Caribbean: At World's End        Orlando Bloom        40000.0
# The Dark Knight Rises                          Christian Bale        27000.0
# Star Wars: Episode VII - The Force Awakens         Rob Walker          131.0
# Tangled                                          Donna Murphy          799.0
# ...                                                       ...            ...
# The Circle                                  Nargess Mamizadeh            5.0
# The Cure                                        Anna Nakagawa           89.0
# The Mongol King                                John Considine           45.0
# Signed Sealed Delivered                         Daphne Zuniga          637.0
# The Following                                   Valorie Curry          841.0
#
#                                                   GROSS  \
# MOVIE_TITLE
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens   25043962.0
# Tangled                                     200807262.0
# ...                                                 ...
# The Circle                                     673780.0
# The Cure                                        94596.0
# The Mongol King                              25043962.0
# Signed Sealed Delivered                      25043962.0
# The Following                                25043962.0
#
#                                                                                        GENRES  \
# MOVIE_TITLE
# Avatar                                                        Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                             Action|Adventure|Fantasy
# The Dark Knight Rises                                                         Action|Thriller
# Star Wars: Episode VII - The Force Awakens                                        Documentary
# Tangled                                     Adventure|Animation|Comedy|Family|Fantasy|Musi...
# ...                                                                                       ...
# The Circle                                                                              Drama
# The Cure                                                        Crime|Horror|Mystery|Thriller
# The Mongol King                                                                   Crime|Drama
# Signed Sealed Delivered                                                          Comedy|Drama
# The Following                                                    Crime|Drama|Mystery|Thriller
#
#                                             ... NUM_USER_FOR_REVIEWS  \
# MOVIE_TITLE                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                153.0
# Tangled                                     ...                387.0
# ...                                         ...                  ...
# The Circle                                  ...                 26.0
# The Cure                                    ...                 50.0
# The Mongol King                             ...                  1.0
# Signed Sealed Delivered                     ...                  6.0
# The Following                               ...                359.0
#
#                                             LANGUAGE  COUNTRY CONTENT_RATING  \
# MOVIE_TITLE
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens   English      USA              R
# Tangled                                      English      USA             PG
# ...                                              ...      ...            ...
# The Circle                                   Persian     Iran      Not Rated
# The Cure                                    Japanese    Japan              R
# The Mongol King                              English      USA          PG-13
# Signed Sealed Delivered                      English   Canada              R
# The Following                                English      USA          TV-14
#
#                                                  BUDGET TITLE_YEAR  \
# MOVIE_TITLE
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens   19850000.0     2005.0
# Tangled                                     260000000.0     2010.0
# ...                                                 ...        ...
# The Circle                                      10000.0     2000.0
# The Cure                                      1000000.0     1997.0
# The Mongol King                                  3250.0     2005.0
# Signed Sealed Delivered                      19850000.0     2013.0
# The Following                                19850000.0     2005.0
#
#                                            ACTOR_2_LIKES  IMDB_SCORE  \
# MOVIE_TITLE
# Avatar                                             936.0         7.9
# Pirates of the Caribbean: At World's End          5000.0         7.1
# The Dark Knight Rises                            23000.0         8.5
# Star Wars: Episode VII - The Force Awakens          12.0         7.1
# Tangled                                            553.0         7.8
# ...                                                  ...         ...
# The Circle                                           0.0         7.5
# The Cure                                            13.0         7.4
# The Mongol King                                     44.0         7.8
# Signed Sealed Delivered                            470.0         7.7
# The Following                                      593.0         7.5
#
#                                            ASPECT_RATIO MOVIE_LIKES
# MOVIE_TITLE
# Avatar                                             1.78       33000
# Pirates of the Caribbean: At World's End           2.35           0
# The Dark Knight Rises                              2.35      164000
# Star Wars: Episode VII - The Force Awakens         2.35           0
# Tangled                                            1.85       29000
# ...                                                 ...         ...
# The Circle                                         1.85         697
# The Cure                                           1.85         817
# The Mongol King                                    2.35           4
# Signed Sealed Delivered                            2.35          84
# The Following                                     16.00       32000
#
# [1546 rows x 27 columns]

# %%
# Display the index to confirm that "_FACEBOOK" suffix is removed from any column names that have it
filtered_df.index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End',
#        'The Dark Knight Rises', 'Star Wars: Episode VII - The Force Awakens',
#        'Tangled', 'Avengers: Age of Ultron',
#        'Harry Potter and the Half-Blood Prince',
#        'Pirates of the Caribbean: Dead Man's Chest', 'Man of Steel',
#        'The Avengers',
#        ...
#        'The Last Waltz', 'Clerks', 'In the Company of Men', 'Slacker',
#        'Stories of Our Lives', 'The Circle', 'The Cure', 'The Mongol King',
#        'Signed Sealed Delivered', 'The Following'],
#       dtype='object', name='MOVIE_TITLE', length=1546)

# %%
# Sort the DataFrame by index (alphabetical order of movie titles)
filtered_df.sort_index(inplace=True)
# Out:
# C:\Users\Habibullah\AppData\Local\Temp\ipykernel_9824\385011128.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.sort_index(inplace=True)

# %%
# Display the sorted DataFrame
filtered_df
# Out:
#                             COLOR        DIRECTOR_NAME  \
# MOVIE_TITLE
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                 Color  Christopher Barnard
# 11:14                       Color          Greg Marcks
# ...                           ...                  ...
# Yours, Mine and Ours        Color   Melville Shavelson
# Zero Dark Thirty            Color      Kathryn Bigelow
# Zodiac                      Color        David Fincher
# Zombieland                  Color      Ruben Fleischer
# [Rec]                       Color      Jaume Balagueró
#
#                             NUM_CRITIC_FOR_REVIEWS  DURATION  \
# MOVIE_TITLE
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# 10 Things I Hate About You                   133.0      97.0
# 10,000 B.C.                                  108.0      22.0
# 11:14                                         68.0      85.0
# ...                                            ...       ...
# Yours, Mine and Ours                           8.0     111.0
# Zero Dark Thirty                             558.0     157.0
# Zodiac                                       377.0     162.0
# Zombieland                                   445.0      88.0
# [Rec]                                        252.0      78.0
#
#                             DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# MOVIE_TITLE
# 10 Cloverfield Lane                            16.0                    82.0
# 10 Days in a Madhouse                           0.0                   247.0
# 10 Things I Hate About You                     19.0                   835.0
# 10,000 B.C.                                     0.0                   366.0
# 11:14                                           9.0                   407.0
# ...                                             ...                     ...
# Yours, Mine and Ours                            5.0                   559.0
# Zero Dark Thirty                                0.0                   304.0
# Zodiac                                      21000.0                   495.0
# Zombieland                                    181.0                    11.0
# [Rec]                                          57.0                     7.0
#
#                                   ACTOR_2_NAME  ACTOR_1_FACEBOOK_LIKES  \
# MOVIE_TITLE
# 10 Cloverfield Lane         John Gallagher Jr.                 14000.0
# 10 Days in a Madhouse            Kelly LeBrock                  1000.0
# 10 Things I Hate About You        Heath Ledger                 23000.0
# 10,000 B.C.                     Morgan Freeman                     5.0
# 11:14                          Barbara Hershey                   861.0
# ...                                        ...                     ...
# Yours, Mine and Ours                Tom Bosley                  6000.0
# Zero Dark Thirty              Harold Perrineau                  1000.0
# Zodiac                         Jake Gyllenhaal                 21000.0
# Zombieland                         Bill Murray                 15000.0
# [Rec]                              Pablo Rosso                   120.0
#
#                                  GROSS                                GENRES  \
# MOVIE_TITLE
# 10 Cloverfield Lane         71897215.0  Drama|Horror|Mystery|Sci-Fi|Thriller
# 10 Days in a Madhouse          14616.0                                 Drama
# 10 Things I Hate About You  38176108.0                  Comedy|Drama|Romance
# 10,000 B.C.                 25043962.0                                Comedy
# 11:14                       25043962.0                    Comedy|Crime|Drama
# ...                                ...                                   ...
# Yours, Mine and Ours        25043962.0                         Comedy|Family
# Zero Dark Thirty            95720716.0                Drama|History|Thriller
# Zodiac                      33048353.0  Crime|Drama|History|Mystery|Thriller
# Zombieland                  75590286.0        Adventure|Comedy|Horror|Sci-Fi
# [Rec]                       25043962.0                                Horror
#
#                             ... NUM_USER_FOR_REVIEWS  LANGUAGE  COUNTRY  \
# MOVIE_TITLE                 ...
# 10 Cloverfield Lane         ...                440.0   English      USA
# 10 Days in a Madhouse       ...                 10.0   English      USA
# 10 Things I Hate About You  ...                549.0   English      USA
# 10,000 B.C.                 ...                153.0   English      USA
# 11:14                       ...                133.0   English      USA
# ...                         ...                  ...       ...      ...
# Yours, Mine and Ours        ...                 61.0   English      USA
# Zero Dark Thirty            ...                640.0   English      USA
# Zodiac                      ...                589.0   English      USA
# Zombieland                  ...                553.0   English      USA
# [Rec]                       ...                374.0   Spanish    Spain
#
#                            CONTENT_RATING      BUDGET TITLE_YEAR  \
# MOVIE_TITLE
# 10 Cloverfield Lane                 PG-13  15000000.0     2016.0
# 10 Days in a Madhouse                   R  12000000.0     2015.0
# 10 Things I Hate About You          PG-13  16000000.0     1999.0
# 10,000 B.C.                             R  19850000.0     2005.0
# 11:14                                   R   6000000.0     2003.0
# ...                                   ...         ...        ...
# Yours, Mine and Ours              Unrated   2500000.0     1968.0
# Zero Dark Thirty                        R  40000000.0     2012.0
# Zodiac                                  R  65000000.0     2007.0
# Zombieland                              R  23600000.0     2009.0
# [Rec]                                   R   1500000.0     2007.0
#
#                            ACTOR_2_FACEBOOK_LIKES  IMDB_SCORE ASPECT_RATIO  \
# MOVIE_TITLE
# 10 Cloverfield Lane                         338.0         7.3         2.35
# 10 Days in a Madhouse                       445.0         7.5         1.85
# 10 Things I Hate About You                13000.0         7.2         1.85
# 10,000 B.C.                                 593.0         7.2         2.35
# 11:14                                       618.0         7.2         1.85
# ...                                           ...         ...          ...
# Yours, Mine and Ours                        584.0         7.2         1.85
# Zero Dark Thirty                           1000.0         7.4         1.85
# Zodiac                                    15000.0         7.7         2.35
# Zombieland                                13000.0         7.7         2.35
# [Rec]                                         9.0         7.5         1.85
#
#                            MOVIE_FACEBOOK_LIKES
# MOVIE_TITLE
# 10 Cloverfield Lane                       33000
# 10 Days in a Madhouse                     26000
# 10 Things I Hate About You                10000
# 10,000 B.C.                                   0
# 11:14                                         0
# ...                                         ...
# Yours, Mine and Ours                          0
# Zero Dark Thirty                          39000
# Zodiac                                    12000
# Zombieland                                26000
# [Rec]                                     15000
#
# [1546 rows x 27 columns]

# %%
# Step 3: Add a New Column
# Adding a 'PROFIT' column, calculated as the difference between 'gross' and 'budget'
filtered_df = filtered_df.assign(PROFIT=filtered_df['GROSS'] - filtered_df['BUDGET'])

# %%
# Display the first few rows of the cleaned and modified dataset
filtered_df.head()
# Out:
#                             COLOR        DIRECTOR_NAME  \
# MOVIE_TITLE
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                 Color  Christopher Barnard
# 11:14                       Color          Greg Marcks
#
#                             NUM_CRITIC_FOR_REVIEWS  DURATION  \
# MOVIE_TITLE
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# 10 Things I Hate About You                   133.0      97.0
# 10,000 B.C.                                  108.0      22.0
# 11:14                                         68.0      85.0
#
#                             DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# MOVIE_TITLE
# 10 Cloverfield Lane                            16.0                    82.0
# 10 Days in a Madhouse                           0.0                   247.0
# 10 Things I Hate About You                     19.0                   835.0
# 10,000 B.C.                                     0.0                   366.0
# 11:14                                           9.0                   407.0
#
#                                   ACTOR_2_NAME  ACTOR_1_FACEBOOK_LIKES  \
# MOVIE_TITLE
# 10 Cloverfield Lane         John Gallagher Jr.                 14000.0
# 10 Days in a Madhouse            Kelly LeBrock                  1000.0
# 10 Things I Hate About You        Heath Ledger                 23000.0
# 10,000 B.C.                     Morgan Freeman                     5.0
# 11:14                          Barbara Hershey                   861.0
#
#                                  GROSS                                GENRES  \
# MOVIE_TITLE
# 10 Cloverfield Lane         71897215.0  Drama|Horror|Mystery|Sci-Fi|Thriller
# 10 Days in a Madhouse          14616.0                                 Drama
# 10 Things I Hate About You  38176108.0                  Comedy|Drama|Romance
# 10,000 B.C.                 25043962.0                                Comedy
# 11:14                       25043962.0                    Comedy|Crime|Drama
#
#                             ... LANGUAGE  COUNTRY  CONTENT_RATING      BUDGET  \
# MOVIE_TITLE                 ...
# 10 Cloverfield Lane         ...  English      USA           PG-13  15000000.0
# 10 Days in a Madhouse       ...  English      USA               R  12000000.0
# 10 Things I Hate About You  ...  English      USA           PG-13  16000000.0
# 10,000 B.C.                 ...  English      USA               R  19850000.0
# 11:14                       ...  English      USA               R   6000000.0
#
#                             TITLE_YEAR ACTOR_2_FACEBOOK_LIKES IMDB_SCORE  \
# MOVIE_TITLE
# 10 Cloverfield Lane             2016.0                  338.0        7.3
# 10 Days in a Madhouse           2015.0                  445.0        7.5
# 10 Things I Hate About You      1999.0                13000.0        7.2
# 10,000 B.C.                     2005.0                  593.0        7.2
# 11:14                           2003.0                  618.0        7.2
#
#                             ASPECT_RATIO MOVIE_FACEBOOK_LIKES      PROFIT
# MOVIE_TITLE
# 10 Cloverfield Lane                 2.35                33000  56897215.0
# 10 Days in a Madhouse               1.85                26000 -11985384.0
# 10 Things I Hate About You          1.85                10000  22176108.0
# 10,000 B.C.                         2.35                    0   5193962.0
# 11:14                               1.85                    0  19043962.0
#
# [5 rows x 28 columns]

# %%
# Display concise summary information about the DataFrame, including data types and memory usage
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1546 entries, 10 Cloverfield Lane to [Rec]
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   COLOR                      1546 non-null   object
#  1   DIRECTOR_NAME              1546 non-null   object
#  2   NUM_CRITIC_FOR_REVIEWS     1546 non-null   float64
#  3   DURATION                   1546 non-null   float64
#  4   DIRECTOR_FACEBOOK_LIKES    1546 non-null   float64
#  5   ACTOR_3_FACEBOOK_LIKES     1546 non-null   float64
#  6   ACTOR_2_NAME               1546 non-null   object
#  7   ACTOR_1_FACEBOOK_LIKES     1546 non-null   float64
#  8   GROSS                      1546 non-null   float64
#  9   GENRES                     1546 non-null   object
#  10  ACTOR_1_NAME               1546 non-null   object
#  11  NUM_VOTED_USERS            1546 non-null   int64
#  12  CAST_TOTAL_FACEBOOK_LIKES  1546 non-null   int64
#  13  ACTOR_3_NAME               1546 non-null   object
#  14  FACENUMBER_IN_POSTER       1546 non-null   float64
#  15  PLOT_KEYWORDS              1546 non-null   object
#  16  MOVIE_IMDB_LINK            1546 non-null   object
#  17  NUM_USER_FOR_REVIEWS       1546 non-null   float64
#  18  LANGUAGE                   1546 non-null   object
#  19  COUNTRY                    1546 non-null   object
#  20  CONTENT_RATING             1546 non-null   object
#  21  BUDGET                     1546 non-null   float64
#  22  TITLE_YEAR                 1546 non-null   float64
#  23  ACTOR_2_FACEBOOK_LIKES     1546 non-null   float64
#  24  IMDB_SCORE                 1546 non-null   float64
#  25  ASPECT_RATIO               1546 non-null   float64
#  26  MOVIE_FACEBOOK_LIKES       1546 non-null   int64
#  27  PROFIT                     1546 non-null   float64
# dtypes: float64(14), int64(3), object(11)
# memory usage: 350.3+ KB
